# %%
import torch
from torch import nn

# %%
emb = nn.Embedding(num_embeddings=1024, embedding_dim=256)

# %%
pos_idx = torch.tensor([10, 5, 2, 32])

# %%
emb(pos_idx)
# Out:
# tensor([[-0.5593, -0.9941,  0.9993,  ...,  0.2343,  0.4382,  0.3166],
#         [-0.1818, -0.1947, -0.4460,  ...,  1.1815,  1.3303, -1.0708],
#         [ 2.0350,  0.1924,  0.2481,  ...,  0.7570,  1.2064,  0.9716],
#         [-1.3683,  0.2284,  1.0492,  ...,  0.4980, -1.0022,  0.9656]],
#        grad_fn=<EmbeddingBackward0>)
